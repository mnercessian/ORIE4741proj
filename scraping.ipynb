# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
url = "https://www.pro-football-reference.com/teams/"

# %%
team_ids = pd.read_csv("Datasets/nfl_teams_with_spaces.csv")

# %%
##finding team abbreviations used by PFR
# url = 'https://www.pro-football-reference.com/years/2019/'
# reqs = requests.get(url) 
# soup = BeautifulSoup(reqs.text, 'html.parser') 
  
# urls = [] 
# for link in soup.find_all('a'): 
#     print(link.get('href'))

# %%
# team_ids
# teams = team_ids["Abbreviation"]
teams = ['crd', 'atl', 'rav', 'buf', 'car', 'chi', 'cin', 'cle', 'dal', 'den', 'det', 'gnb', 'htx', 'clt',  
               'jax', 'kan', 'mia', 'min', 'nwe', 'nor', 'nyg', 'nyj', 'rai', 'phi', 'pit', 'sdg', 'sfo', 'sea',
                'ram', 'tam', 'oti', 'was']

# %%
def process(data, team):
    assert 16 <= data.shape[0] <= 22
    assert data.shape[1] == 25 #confirm we are getting the right table
    data.insert(0, "Team", (teams.index(team) + 1)*np.ones(data.shape[0]))
    return data

# %%
#returns a dataframe containing all game data from the given year from Pro Football Reference
#with team and year identifiers added
def get_year_data(year):
    team = teams[0]
    year_data = pd.read_html(url + team + "/" + str(year) + ".htm")[1] #take in the first team so we can append in the loop
    year_data = process(year_data, team)
#     assert 17 <= year_data.shape[0] <= 22
#     assert year_data.shape[1] == 25 #confirm we are getting the right table
#     year_data.insert(0, "Team", (teams.index(team) + 1)*np.ones(year_data.shape[0]))
    
    for team in teams[1:]:
        team_data = pd.read_html(url + team + "/" + str(year) + ".htm")[1]  #gets the table from the URL
#         assert 16 <= team_data.shape[0] <= 22   #16 is the minimum bc week 1 bye is eliminated from table, see 2017 dolphins
#         assert team_data.shape[1] == 25 #confirm we are getting the right table
#         team_data.insert(0, "Team", (teams.index(team) + 1)*np.ones(team_data.shape[0]))   #inserts team ID
        team_data = process(team_data, team)
        year_data = year_data.append(team_data)    #appends to year dataset
        print(str(year) + ' ' + team)   #for debugging purposes
    year_data.insert(0, "Year", year*np.ones(year_data.shape[0]))    #adds year ID
    return year_data

# %%
#concatenates datasets year over year
first_year = 2000
last_year = 2001

all_data = get_year_data(last_year)
for i in range(last_year-1, first_year-1, -1):  
    all_data = all_data.append(get_year_data(i))
# Out:
# 2001 atl
# 2001 rav
# 2001 buf
# 2001 car
# 2001 chi
# 2001 cin
# 2001 cle
# 2001 dal
# 2001 den
# 2001 det
# 2001 gnb
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-284f98a636e0> in <module>
#       3 last_year = 2001
#       4
# ----> 5 all_data = get_year_data(last_year)
#       6 for i in range(last_year-1, first_year-1, -1):
#       7     all_data = all_data.append(get_year_data(i))
#
# <ipython-input-7-3b218983204a> in get_year_data(year)
#      10
#      11     for team in teams[1:]:
# ---> 12         team_data = pd.read_html(url + team + "/" + str(year) + ".htm")[1]  #gets the table from the URL
#      13 #         assert 16 <= team_data.shape[0] <= 22   #16 is the minimum bc week 1 bye is eliminated from table, see 2017 dolphins
#      14 #         assert team_data.shape[1] == 25 #confirm we are getting the right table
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083         )
#    1084     validate_header_arg(header)
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     893
#     894         try:
# --> 895             tables = p.parse_tables()
#     896         except ValueError as caught:
#     897             # if `io` is an io-like object, check if it's seekable
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in parse_tables(self)
#     211         list of parsed (header, body, footer) tuples from tables.
#     212         """
# --> 213         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     214         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     215
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _build_doc(self)
#     731                     pass
#     732             else:
# --> 733                 raise e
#     734         else:
#     735             if not hasattr(r, "text_content"):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/html.py in _build_doc(self)
#     712         try:
#     713             if is_url(self.io):
# --> 714                 with urlopen(self.io) as f:
#     715                     r = parse(f, parser=parser)
#     716             else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     139     import urllib.request
#     140
# --> 141     return urllib.request.urlopen(*args, **kwargs)
#     142
#     143
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
# all_data.to_csv('Datasets/2010_thru_2012.csv', index = False)
data_02_09 = all_data.copy()
data_02_09.to_csv('Datasets/2002_thru_2009.csv', index = False)
new = pd.read_csv('Datasets/2002_thru_2009.csv')

# %%
old = pd.read_csv('Datasets/2010_thru_2019.csv')

# %%
full = old.append(new)

# %%
# old = pd.read_csv('2013_thru_2019.csv', header = [0,1])
full.to_csv('2002_thru_2019.csv', index = False)

# %%
new = pd.read_csv('2010_thru_2012.csv', header = [0,1])

# %%
# team_data = pd.read_html(url + teams[16] + "/" + '2017' + ".htm")[1]  #gets the table from the URL

# %%
# team_data.shape

# %%
#debugging

# year = 2017
# for team in teams[1:]:
#     team_data = pd.read_html(url + team + "/" + str(year) + ".htm")[1]  #gets the table from the URL
#     assert 16 <= team_data.shape[0] <= 21
#     assert team_data.shape[1] == 25 #confirm we are getting the right table
#     team_data.insert(0, "Team", (teams.index(team) + 1)*np.ones(team_data.shape[0]))
#     print(str(year) + ' ' + team + ' ' + i)

# %%
url_p = "https://www.pro-football-reference.com/teams/buf/2018.htm"
site = pd.read_html(url_p)

# %%
games = site[1]

# %%
games
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Week                Day               Date
# 0                   1                Sun        September 9
# 1                   2                Sun       September 16
# 2                   3                Sun       September 23
# 3                   4                Sun       September 30
# 4                   5                Sun          October 7
# 5                   6                Sun         October 14
# 6                   7                Sun         October 21
# 7                   8                Mon         October 29
# 8                   9                Sun         November 4
# 9                  10                Sun        November 11
# 10                 11                NaN                NaN
# 11                 12                Sun        November 25
# 12                 13                Sun         December 2
# 13                 14                Sun         December 9
# 14                 15                Sun        December 16
# 15                 16                Sun        December 23
# 16                 17                Sun        December 30
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#    Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0           1:00PM ET           boxscore                  L
# 1           1:00PM ET           boxscore                  L
# 2           1:00PM ET           boxscore                  W
# 3           1:00PM ET           boxscore                  L
# 4           1:00PM ET           boxscore                  W
# 5           1:00PM ET           boxscore                  L
# 6           1:00PM ET           boxscore                  L
# 7           8:15PM ET           boxscore                  L
# 8           1:00PM ET           boxscore                  L
# 9           1:00PM ET           boxscore                  W
# 10                NaN                NaN                NaN
# 11          1:00PM ET           boxscore                  W
# 12          1:00PM ET           boxscore                  L
# 13          1:00PM ET           boxscore                  L
# 14          1:00PM ET           boxscore                  W
# 15          1:00PM ET           boxscore                  L
# 16          1:00PM ET           boxscore                  W
#
#    Unnamed: 6_level_0 Unnamed: 7_level_0 Unnamed: 8_level_0  \
#                    OT                Rec Unnamed: 8_level_1
# 0                 NaN                0-1                  @
# 1                 NaN                0-2                NaN
# 2                 NaN                1-2                  @
# 3                 NaN                1-3                  @
# 4                 NaN                2-3                NaN
# 5                 NaN                2-4                  @
# 6                 NaN                2-5                  @
# 7                 NaN                2-6                NaN
# 8                 NaN                2-7                NaN
# 9                 NaN                3-7                  @
# 10                NaN                NaN                NaN
# 11                NaN                4-7                NaN
# 12                NaN                4-8                  @
# 13                NaN                4-9                NaN
# 14                NaN                5-9                NaN
# 15                NaN               5-10                  @
# 16                NaN               6-10                NaN
#
#       Unnamed: 9_level_0 Score       Offense                            \
#                      Opp    Tm   Opp    1stD  TotYd  PassY  RushY   TO
# 0       Baltimore Ravens   3.0  47.0    10.0  153.0   70.0   83.0  2.0
# 1   Los Angeles Chargers  20.0  31.0    17.0  293.0  209.0   84.0  2.0
# 2      Minnesota Vikings  27.0   6.0    16.0  292.0  164.0  128.0  NaN
# 3      Green Bay Packers   0.0  22.0    11.0  145.0   87.0   58.0  3.0
# 4       Tennessee Titans  13.0  12.0    18.0  223.0   79.0  144.0  1.0
# 5         Houston Texans  13.0  20.0    12.0  229.0  129.0  100.0  3.0
# 6     Indianapolis Colts   5.0  37.0    15.0  303.0  168.0  135.0  5.0
# 7   New England Patriots   6.0  25.0    16.0  333.0  287.0   46.0  2.0
# 8          Chicago Bears   9.0  41.0    22.0  264.0  166.0   98.0  4.0
# 9          New York Jets  41.0  10.0    23.0  451.0  239.0  212.0  NaN
# 10              Bye Week   NaN   NaN     NaN    NaN    NaN    NaN  NaN
# 11  Jacksonville Jaguars  24.0  21.0    18.0  327.0  160.0  167.0  NaN
